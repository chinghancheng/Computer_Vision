# %%
from ssd import build_ssd
from layers.box_utils import *
import os
import sys
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torch.nn.init as init
import torch.utils.data as data
import numpy as np
import argparse
import torchvision
import pickle
from layers import box_utils
from layers import Detect
from layers import functions
from layers import modules
import torch.nn.functional as F
from math import sqrt as sqrt
from itertools import product as product

from torch.autograd import Function
from layers.box_utils import decode, nms

# %%
## 詳細模型結構可以參考ssd.py
ssd_net=build_ssd('train', size=300, num_classes=21)
ssd_net.load_weights('./demo/ssd300_mAP_77.43_v2.pth')
# Out:
# d:\PyProjects\Computer_Vision_ori\Day029_031\Object Detection\ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)
# Loading weights into state dict...
# Finished!

# %% [markdown]
# ## 默認Config檔案在data/config.py內

# %%
ssd_net.cfg
# Out:
# {'num_classes': 21,
#  'lr_steps': (80000, 100000, 120000),
#  'max_iter': 120000,
#  'feature_maps': [38, 19, 10, 5, 3, 1],
#  'min_dim': 300,
#  'steps': [8, 16, 32, 64, 100, 300],
#  'min_sizes': [30, 60, 111, 162, 213, 264],
#  'max_sizes': [60, 111, 162, 213, 264, 315],
#  'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
#  'variance': [0.1, 0.2],
#  'clip': True,
#  'name': 'VOC'}

# %%
cfg = {
    'num_classes': 21,
    'lr_steps': (80000, 100000, 120000),
    'max_iter': 120000,
    'feature_maps': [38, 19, 10, 5, 3, 1],
    'min_dim': 300,
    'steps': [8, 16, 32, 64, 100, 300],
    'min_sizes': [30, 60, 111, 162, 213, 264],
    'max_sizes': [60, 111, 162, 213, 264, 315],
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
    'variance': [0.1, 0.2],
    'clip': True,
    'name': 'VOC',
}

# %% [markdown]
# ### 'aspect_ratios' : 使用六張Feature Map，每一張上方有預設的anchor boxes，Boxes aspect ratio可以自己設定
# ### 'feature_maps' : 使用feature map大小為[38x38, 19x19, 10x10, 5x5, 3x3, 1x1]
# ### 'min_sizes'、'max_sizes'可藉由下方算式算出，由作者自行設計
# ### 'steps' : Feature map回放回原本300*300的比例，如38要回放為300大概就是8倍
# ### 'variance' : Training 的一個trick，加速收斂，詳見：https://github.com/rykov8/ssd_keras/issues/53

# %% [markdown]
# ---

# %% [markdown]
# ## 'min_sizes'、'max_sizes' 計算

# %%
import math
## source:https://blog.csdn.net/gbyy42299/article/details/81235891
min_dim = 300   ## 维度
# conv4_3 ==> 38 x 38
# fc7 ==> 19 x 19
# conv6_2 ==> 10 x 10
# conv7_2 ==> 5 x 5
# conv8_2 ==> 3 x 3
# conv9_2 ==> 1 x 1
mbox_source_layers = ['conv4_3', 'fc7', 'conv6_2', 'conv7_2', 'conv8_2', 'conv9_2'] ## prior_box來源層，可以更改。很多改進都是基於此處的調整。
# in percent %
min_ratio = 20 ## 這裡即是論文中所說的Smin的= 0.2，Smax的= 0.9的初始值，經過下面的運算即可得到min_sizes，max_sizes。
max_ratio = 90
step = int(math.floor((max_ratio - min_ratio) / (len(mbox_source_layers) - 2)))## 取一個間距步長，即在下面用於循環給比取值時起一個間距作用。可以用一個具體的數值代替，這裡等於17。
min_sizes = []  ## 經過以下運算得到min_sizes和max_sizes。
max_sizes = []
for ratio in range(min_ratio, max_ratio + 1, step):
    ## 從min_ratio至max_ratio + 1每隔步驟= 17取一個值賦值給比。注意範圍函數的作用。
    ## min_sizes.append（）函數即把括號內部每次得到的值依次給了min_sizes。
    min_sizes.append(min_dim * ratio / 100.)
    max_sizes.append(min_dim * (ratio + step) / 100.)
min_sizes = [min_dim * 10 / 100.] + min_sizes
max_sizes = [min_dim * 20 / 100.] + max_sizes

## steps: 這一步要仔細理解，即計算卷積層產生的prior_box距離原圖的步長，先驗框中心點的坐標會乘以step，
## 相當於從特徵映射位置映射回原圖位置，比如conv4_3輸出特徵圖大小為38 *38，而輸入的圖片為300* 300，
## 所以38 *8約等於300，所以映射步長為8.這是針對300* 300的訓練圖片。
steps = [8, 16, 32, 64, 100, 300]  
aspect_ratios = [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
 
print('min_sizes: ',min_sizes)
print('max_sizes: ',max_sizes)
# Out:
# min_sizes:  [30.0, 60.0, 111.0, 162.0, 213.0, 264.0]
# max_sizes:  [60.0, 111.0, 162.0, 213.0, 264.0, 315.0]

# %% [markdown]
# ---

# %% [markdown]
# ## Default anchor boxes設計原理，看懂收穫很多
# ##### 可以理解 SSD原文中 8732個anchors是怎麼來的
# ##### 38×38×4+19×19×6+10×10×6+5×5×6+3×3×4+1×1×4=8732

# %%
class PriorBox(object):
    """Compute priorbox coordinates in center-offset form for each source
    feature map.
    """
    def __init__(self, cfg):
        super(PriorBox, self).__init__()
        self.image_size = cfg['min_dim']
        # number of priors for feature map location (either 4 or 6)
        self.num_priors = len(cfg['aspect_ratios'])
        self.variance = cfg['variance'] or [0.1]
        self.feature_maps = cfg['feature_maps']
        self.min_sizes = cfg['min_sizes']
        self.max_sizes = cfg['max_sizes']
        self.steps = cfg['steps']
        self.aspect_ratios = cfg['aspect_ratios']
        self.clip = cfg['clip']
        self.version = cfg['name']
        for v in self.variance:
            if v <= 0:
                raise ValueError('Variances must be greater than 0')

    def forward(self):
        mean = []
        '''依照Feature map大小找出所有的pixel 中心'''
        '''下方這兩個loop會找出W個x軸pixel對上W個y軸pixel，假如現在是在38x38的feature map上，就會有38x38個值'''
        '''ex. [0,1],[0,2]..[0,37] [1,1],[1,2]..[1,37]..........[37,37]'''
        for k, f in enumerate(self.feature_maps):
            for i, j in product(range(f), repeat=2):
                f_k = self.image_size / self.steps[k] ## 如self.steps==8，就是先將原圖size normalize(/300)後再乘上8
                # unit center x,y
                '''中心點'''
                cx = (j + 0.5) / f_k
                cy = (i + 0.5) / f_k

                # aspect_ratio: 1
                # rel size: min_size
                '''/self.image_size 就是在做normalization '''
                s_k = self.min_sizes[k]/self.image_size
                '''小的正方形box'''
                mean += [cx, cy, s_k, s_k]

                # aspect_ratio: 1
                # rel size: sqrt(s_k * s_(k+1))
                '''大的正方形box'''
                s_k_prime = sqrt(s_k * (self.max_sizes[k]/self.image_size))
                mean += [cx, cy, s_k_prime, s_k_prime]

                # rest of aspect ratios
                for ar in self.aspect_ratios[k]:
                    '''aspect ratio 2,3'''
                    mean += [cx, cy, s_k*sqrt(ar), s_k/sqrt(ar)]
                    '''aspect ratio 1/2,1/3'''
                    mean += [cx, cy, s_k/sqrt(ar), s_k*sqrt(ar)]
        # back to torch land
        output = torch.Tensor(mean).view(-1, 4)
        if self.clip:
            output.clamp_(max=1, min=0)
        return output

# %%
PriorBox_Demo=PriorBox(cfg)

# %%
print(PriorBox_Demo.forward().shape)
# Out:
# torch.Size([8732, 4])

# %% [markdown]
# ---

# %% [markdown]
# ## Loss 如何設計

# %%
class MultiBoxLoss(nn.Module):

    def __init__(self, num_classes, overlap_thresh, prior_for_matching,
                 bkg_label, neg_mining, neg_pos, neg_overlap, encode_target,
                 use_gpu=True):
        super(MultiBoxLoss, self).__init__()
        self.use_gpu = use_gpu
        '''有幾類'''
        self.num_classes = num_classes
        '''判定為正樣本的threshold，一般設為0.5'''
        self.threshold = overlap_thresh
        '''background自己會有一類，不用Label，假如我們有20類一樣標註0-19，下方會自己空出一類給background'''
        self.background_label = bkg_label
        self.encode_target = encode_target
        self.use_prior_for_matching = prior_for_matching
        '''OHEM，找出分得最不好的樣品，也就是confidence score比較低的正負樣品'''
        self.do_neg_mining = neg_mining
        '''負樣品與正樣品的比例，通常是3:1'''
        self.negpos_ratio = neg_pos
        self.neg_overlap = neg_overlap
        self.variance = cfg['variance']
     

    def forward(self, predictions, targets):

        '''prediction會output三個值'''
        '''loc shape: bounding box 資訊，torch.size(batch_size,num_priors,4)'''
        '''conf shape: 每一個bounding box 的信心程度，torch.size(batch_size,num_priors,num_classes)'''
        '''priors shape: 預設的defaul box， torch.size(num_priors,4)'''
        loc_data, conf_data, priors = predictions
        num = loc_data.size(0)
        priors = priors[:loc_data.size(1), :]
        num_priors = (priors.size(0))
        num_classes = self.num_classes

        # match priors (default boxes) and ground truth boxes
        loc_t = torch.Tensor(num, num_priors, 4)
        conf_t = torch.LongTensor(num, num_priors)
        for idx in range(num):
            truths = targets[idx][:, :-1].data
            labels = targets[idx][:, -1].data
            defaults = priors.data
            '''jaccard 計算每一個BBOX與ground truth的IOU'''
            match(self.threshold, truths, defaults, self.variance, labels,
                  loc_t, conf_t, idx)
        if self.use_gpu:
            loc_t = loc_t.cuda()
            conf_t = conf_t.cuda()
        '''用Variable包裝'''
        loc_t = Variable(loc_t, requires_grad=False)
        conf_t = Variable(conf_t, requires_grad=False)

        pos = conf_t > 0
        num_pos = pos.sum(dim=1, keepdim=True)


        pos_idx = pos.unsqueeze(pos.dim()).expand_as(loc_data)
        loc_p = loc_data[pos_idx].view(-1, 4)
        loc_t = loc_t[pos_idx].view(-1, 4)
        '''smooth_l1_loss 計算bounding box regression'''
        loss_l = F.smooth_l1_loss(loc_p, loc_t, size_average=False)

        # Compute max conf across batch for hard negative mining
        batch_conf = conf_data.view(-1, self.num_classes)
        loss_c = log_sum_exp(batch_conf) - batch_conf.gather(1, conf_t.view(-1, 1))

        # Hard Negative Mining
        loss_c = loss_c.view(num, -1)
        loss_c[pos] = 0
        '''排列confidence 的分數'''
        _, loss_idx = loss_c.sort(1, descending=True)
        _, idx_rank = loss_idx.sort(1)
        num_pos = pos.long().sum(1, keepdim=True)
        '''負樣品取出數量 == negpos_ratio*num_pos'''
        num_neg = torch.clamp(self.negpos_ratio*num_pos, max=pos.size(1)-1)
        neg = idx_rank < num_neg.expand_as(idx_rank)

        # Confidence Loss Including Positive and Negative Examples
        pos_idx = pos.unsqueeze(2).expand_as(conf_data)
        neg_idx = neg.unsqueeze(2).expand_as(conf_data)
        conf_p = conf_data[(pos_idx+neg_idx).gt(0)].view(-1, self.num_classes)
        targets_weighted = conf_t[(pos+neg).gt(0)]
        '''用cross_entropy做分類'''
        loss_c = F.cross_entropy(conf_p, targets_weighted, size_average=False)

        # Sum of losses: L(x,c,l,g) = (Lconf(x, c) + αLloc(x,l,g)) / N
        #double轉成torch.float64
        N = num_pos.data.sum().double()
        loss_l = loss_l.double()
        loss_c = loss_c.double()
        loss_l /= N
        loss_c /= N
        return loss_l, loss_c

# %% [markdown]
# ## 產生我們Loss function，注意這裡的class要包含背景

# %%
Use_cuda=False
criterion = MultiBoxLoss(21, 0.5, True, 0, False, 3, 0.5,False, Use_cuda,)

# %% [markdown]
# ----

# %% [markdown]
# ## 基本設定

# %%
ssd_net=build_ssd('train', size=300, num_classes=21)
use_pretrained=True
if use_pretrained:
    ssd_net.load_weights('./demo/ssd300_mAP_77.43_v2.pth')
net=ssd_net
# Out:
# Loading weights into state dict...
# Finished!

# %%
'''要不要使用gpu'''
Use_cuda=False

'''tensor type會依照cpu或gpu有所不同'''
if torch.cuda.is_available():
    if args.cuda:
        torch.set_default_tensor_type('torch.cuda.FloatTensor')
    if not args.cuda:
        print("WARNING: It looks like you have a CUDA device, but aren't " +
              "using CUDA.\nRun with --cuda for optimal training speed.")
        torch.set_default_tensor_type('torch.FloatTensor')
else:
    torch.set_default_tensor_type('torch.FloatTensor')

'''使用GPU時可以開啟DataParallel，但當Input是不定大小時，要關掉'''
if Use_cuda:
    net = torch.nn.DataParallel(ssd_net)
    cudnn.benchmark = True
'''使用GPU時模型要轉成cuda'''
if Use_cuda:
    net = net.cuda()
    
batch_size_=1
optimizer = optim.Adam(net.parameters(),lr=0.00001/batch_size_)

# %% [markdown]
# ---

# %% [markdown]
# ## 訓練

# %% [markdown]
# ## 這裡我們先示範輸入的 image,Label格式，真正在訓練時，準備成一樣格式即可

# %%
'''輸入影像格式，假設batch size 為 4'''
image_in=torch.tensor(torch.rand(4,3,300,300),dtype=torch.float32)
'''Label格式，沒有固定長度，看圖像中有幾個label就有幾個'''
label_0=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 19.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
label_1=[[ 0.1804,  0.6076,  0.7701,  0.8485, 13.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 11.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 7.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 5.0000],]
label_2=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 14.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
label_3=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 19.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
# Out:
# d:\PyProjects\Computer_Vision_ori\venv\lib\site-packages\ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
epochs=30
iteration=100

# %%
for epoch in range(epochs):
    n=0
    loss_sum=[]
    loc_loss=[]
    conf_loss=[]
    for number__ in range(iteration) :
        '''要用Variable包裝tensor才能送入模型'''
        if Use_cuda:
            image_ = Variable(image_in.cuda())
            y = [Variable(torch.tensor(label_0).cuda(), volatile=True),Variable(torch.tensor(label_1).cuda(), 
                volatile=True),Variable(torch.tensor(label_2).cuda(), volatile=True),Variable(torch.tensor(label_3).cuda(), volatile=True)]      
        else:
            image_ = Variable(image_in)
            y = [Variable(torch.tensor(label_0), volatile=True),Variable(torch.tensor(label_1), 
                volatile=True),Variable(torch.tensor(label_2), volatile=True),Variable(torch.tensor(label_3), volatile=True)]

        '''Forward Pass'''
        out = net(image_)
        '''Regression Loss and Classification Loss'''
        loss_l,loss_c = criterion(out,y )
        loss = loss_l+ loss_c
        '''Backward'''
        loss.backward()

        loc_loss.append(loss_l.data.cpu().numpy())
        conf_loss.append(loss_c.data.cpu().numpy())
        loss_sum.append(loss.data.cpu().numpy())
        '''更新參數'''
        optimizer.step()
        '''清空Gradients'''
        optimizer.zero_grad()
        
        n+=1
        if n%10==0:
            print('BBOX Regression Loss: ', np.mean(loc_loss))
            print('Classification Loss: ', np.mean(conf_loss))
    '''儲存權重'''
    torch.save(ssd_net.state_dict(),'weights/Weights.pth')
# Out:
# 165
# BBOX Regression Loss:  0.0008118196883077433
# Classification Loss:  0.0002735298448156014
# BBOX Regression Loss:  0.0007294863872446836
# Classification Loss:  0.00027455392949007174
# BBOX Regression Loss:  0.0006597496617043226
# Classification Loss:  0.00027390178396470024
# BBOX Regression Loss:  1.3132456418437264e-05
# Classification Loss:  0.00025444290842171064
# BBOX Regression Loss:  9.775726707798808e-06
# Classification Loss:  0.0002483287489869528
# BBOX Regression Loss:  7.91328070422255e-06
# Classification Loss:  0.000242550248556115
# BBOX Regression Loss:  6.730828432342537e-06
# Classification Loss:  0.00023697297718306933
# BBOX Regression Loss:  5.923126882407813e-06
# Classification Loss:  0.00023168489888862327
# BBOX Regression Loss:  5.3514742179641525e-06
# Classification Loss:  0.0002266832380153146
# BBOX Regression Loss:  1.9282409761140427e-05
# Classification Loss:  0.0002220244772692837
# BBOX Regression Loss:  0.0007765671925476959
# Classification Loss:  0.00022177621291053512
# BBOX Regression Loss:  0.0008597013235394938
# Classification Loss:  0.0002281534562170996
# BBOX Regression Loss:  0.0008212592955075067
# Classification Loss:  0.0002336359413823596
# BBOX Regression Loss:  0.0001722198747167433
# Classification Loss:  0.0002715522906294575
# BBOX Regression Loss:  0.00011817439840847831
# Classification Loss:  0.00026559719591642974
# BBOX Regression Loss:  8.703365431161435e-05
# Classification Loss:  0.00025892876502540377
# BBOX Regression Loss:  6.806112039528132e-05
# Classification Loss:  0.0002523218592007955
# BBOX Regression Loss:  5.562980202268119e-05
# Classification Loss:  0.000246037871197418
# BBOX Regression Loss:  4.717273223371947e-05
# Classification Loss:  0.00024011736551736608
# BBOX Regression Loss:  5.430147179929667e-05
# Classification Loss:  0.00023459226937678752
# BBOX Regression Loss:  0.00027803252278654663
# Classification Loss:  0.00023218186106532812
# BBOX Regression Loss:  0.0003101879370555957
# Classification Loss:  0.00023073229934912894
# BBOX Regression Loss:  0.0002999438952947795
# Classification Loss:  0.0002291429101454991
# BBOX Regression Loss:  7.464198731920785e-05
# Classification Loss:  0.00020810176135489236
# BBOX Regression Loss:  5.3669527740028026e-05
# Classification Loss:  0.00020341458902866754
# BBOX Regression Loss:  4.03616507322079e-05
# Classification Loss:  0.00019870223362504702
# BBOX Regression Loss:  3.1671192785627986e-05
# Classification Loss:  0.00019420193059852827
# BBOX Regression Loss:  2.604748970177887e-05
# Classification Loss:  0.0001899575545556015
# BBOX Regression Loss:  2.210004211430018e-05
# Classification Loss:  0.0001859523200740417
# BBOX Regression Loss:  1.9698653652864908e-05
# Classification Loss:  0.0001821701922429302
# BBOX Regression Loss:  0.00013776277392699504
# Classification Loss:  0.00017888871866657779
# BBOX Regression Loss:  0.0004045306462166953
# Classification Loss:  0.00017912238663821307
# BBOX Regression Loss:  0.00042200048907910015
# Classification Loss:  0.00018071459226862144
# BBOX Regression Loss:  0.00018553277348271673
# Classification Loss:  0.00019295579512362127
# BBOX Regression Loss:  0.00012690090645466826
# Classification Loss:  0.00018981357743204743
# BBOX Regression Loss:  9.293685890705451e-05
# Classification Loss:  0.00018597494086457624
# BBOX Regression Loss:  7.231362054611694e-05
# Classification Loss:  0.0001818098563321487
# BBOX Regression Loss:  5.883096665018929e-05
# Classification Loss:  0.00017770159265233413
# BBOX Regression Loss:  4.949324750972058e-05
# Classification Loss:  0.00017379056518598474
# BBOX Regression Loss:  4.269256150923121e-05
# Classification Loss:  0.00017007907788471255
# BBOX Regression Loss:  3.754427571544107e-05
# Classification Loss:  0.00016657761190328057
# BBOX Regression Loss:  3.351676239340553e-05
# Classification Loss:  0.00016324548002853684
# BBOX Regression Loss:  3.028508142489483e-05
# Classification Loss:  0.00016010656159509112
# BBOX Regression Loss:  1.1715282636470403e-06
# Classification Loss:  0.00012720252335485485
# BBOX Regression Loss:  2.1087150647266148e-06
# Classification Loss:  0.00012505832257577113
# BBOX Regression Loss:  0.0003149615030800047
# Classification Loss:  0.00012335450572456108
# BBOX Regression Loss:  0.0013886456622997313
# Classification Loss:  0.00013285390472177555
# BBOX Regression Loss:  0.0013285893915383862
# Classification Loss:  0.0001452798903402355
# BBOX Regression Loss:  0.001170299558885116
# Classification Loss:  0.00015362076041645112
# BBOX Regression Loss:  0.0010240336411635525
# Classification Loss:  0.00015853269385400587
# BBOX Regression Loss:  0.0009021868868886587
# Classification Loss:  0.00016101899586997375
# BBOX Regression Loss:  0.0008042606404021839
# Classification Loss:  0.00016181274152403014
# BBOX Regression Loss:  0.0007246909675140395
# Classification Loss:  0.00016148524203648168
# BBOX Regression Loss:  3.945959448443587e-06
# Classification Loss:  0.00015018827074931727
# BBOX Regression Loss:  3.1527597591910444e-06
# Classification Loss:  0.00014642097219755805
# BBOX Regression Loss:  2.6554997964046415e-06
# Classification Loss:  0.00014298071992802032
# BBOX Regression Loss:  2.3275682569537485e-06
# Classification Loss:  0.00013979353415952237
# BBOX Regression Loss:  2.0964544927227066e-06
# Classification Loss:  0.00013682796102431084
# BBOX Regression Loss:  1.9286886852591753e-06
# Classification Loss:  0.00013404522870126884
# BBOX Regression Loss:  1.7991010940811722e-06
# Classification Loss:  0.00013143042467100906
# BBOX Regression Loss:  1.7087209471355891e-06
# Classification Loss:  0.00012897398652664073
# BBOX Regression Loss:  7.256337067765307e-06
# Classification Loss:  0.00012666190583488824
# BBOX Regression Loss:  0.0004477765135932175
# Classification Loss:  0.00012604864891963422
# BBOX Regression Loss:  0.0018117000521333131
# Classification Loss:  0.00017746402192170973
# BBOX Regression Loss:  0.0011665559873950703
# Classification Loss:  0.00018226360229568346
# BBOX Regression Loss:  0.0008373862565035161
# Classification Loss:  0.00018155190254343144
# BBOX Regression Loss:  0.0006439301012303785
# Classification Loss:  0.00017894310057508172
# BBOX Regression Loss:  0.0005202669281020967
# Classification Loss:  0.0001754035283293989
# BBOX Regression Loss:  0.00043527939495016866
# Classification Loss:  0.00017138375601742734
# BBOX Regression Loss:  0.0003737546452612151
# Classification Loss:  0.00016740247774770653
# BBOX Regression Loss:  0.0003273560453096622
# Classification Loss:  0.00016343721966862818
# BBOX Regression Loss:  0.00029117997229924966
# Classification Loss:  0.00015957571945532603
# BBOX Regression Loss:  0.0002622039562144588
# Classification Loss:  0.0001558740476698235
# BBOX Regression Loss:  1.2318731966876872e-06
# Classification Loss:  0.00011717794652752305
# BBOX Regression Loss:  1.1662609924517003e-06
# Classification Loss:  0.00011471875305115074
# BBOX Regression Loss:  1.1092513797152209e-06
# Classification Loss:  0.0001124111771652544
# BBOX Regression Loss:  1.0608504301975093e-06
# Classification Loss:  0.00011026435962843673
# BBOX Regression Loss:  1.0829239599169577e-06
# Classification Loss:  0.0001082294241145805
# BBOX Regression Loss:  3.565963753755096e-05
# Classification Loss:  0.00010637240656824025
# BBOX Regression Loss:  0.0007085469761742392
# Classification Loss:  0.00010810110609603937
# BBOX Regression Loss:  0.0007519595733263621
# Classification Loss:  0.00011329247478257727
# BBOX Regression Loss:  0.0007055684965094104
# Classification Loss:  0.00011771410922117439
# BBOX Regression Loss:  0.0006465083518270585
# Classification Loss:  0.00012064371370124044
# BBOX Regression Loss:  4.26883643268849e-05
# Classification Loss:  0.00013960157434835479
# BBOX Regression Loss:  2.9543159137204006e-05
# Classification Loss:  0.00013623582889084465
# BBOX Regression Loss:  2.194920360372275e-05
# Classification Loss:  0.0001326866134610257
# BBOX Regression Loss:  1.725955601243725e-05
# Classification Loss:  0.00012926345527241077
# BBOX Regression Loss:  1.4189166195811361e-05
# Classification Loss:  0.00012602847448929592
# BBOX Regression Loss:  1.2050714996556414e-05
# Classification Loss:  0.0001230114164049335
# BBOX Regression Loss:  1.0485043342683528e-05
# Classification Loss:  0.00012020095443678278
# BBOX Regression Loss:  9.295764615065614e-06
# Classification Loss:  0.00011756489876899178
# BBOX Regression Loss:  8.362523164387426e-06
# Classification Loss:  0.00011509589097796031
# BBOX Regression Loss:  7.609199697240171e-06
# Classification Loss:  0.00011278852277124923
# BBOX Regression Loss:  7.704642215415973e-07
# Classification Loss:  8.889447242297508e-05
# BBOX Regression Loss:  7.515868000390819e-07
# Classification Loss:  8.73828405962774e-05
# BBOX Regression Loss:  3.2313099668331067e-06
# Classification Loss:  8.592734050097658e-05
# BBOX Regression Loss:  0.0013392759409877422
# Classification Loss:  8.606685743736173e-05
# BBOX Regression Loss:  0.0016315632044804965
# Classification Loss:  9.640307648590317e-05
# BBOX Regression Loss:  0.0015307939628925208
# Classification Loss:  0.00010804034809777398
# BBOX Regression Loss:  0.0013599069961779007
# Classification Loss:  0.00011655762298870338
# BBOX Regression Loss:  0.0012045134295165015
# Classification Loss:  0.00012204791289857691
# BBOX Regression Loss:  0.001075584653626121
# Classification Loss:  0.00012528399243153662
# BBOX Regression Loss:  0.0009697845216410145
# Classification Loss:  0.00012694774126565018
# BBOX Regression Loss:  7.5238118168070085e-06
# Classification Loss:  0.00013296887692477966
# BBOX Regression Loss:  5.5835594038297946e-06
# Classification Loss:  0.00012897320212451396
# BBOX Regression Loss:  4.441805849862169e-06
# Classification Loss:  0.0001256320622669142
# BBOX Regression Loss:  3.710883828278855e-06
# Classification Loss:  0.00012243686015372753
# BBOX Regression Loss:  3.2247327531136023e-06
# Classification Loss:  0.00011932136318473903
# BBOX Regression Loss:  2.8794213679326655e-06
# Classification Loss:  0.00011638199298263149
# BBOX Regression Loss:  2.6195985103388214e-06
# Classification Loss:  0.00011362588961938858
# BBOX Regression Loss:  2.4135960656066243e-06
# Classification Loss:  0.00011105333040985796
# BBOX Regression Loss:  2.2438478354235766e-06
# Classification Loss:  0.00010864425933471432
# BBOX Regression Loss:  2.1010201251354176e-06
# Classification Loss:  0.0001063799338104824
# BBOX Regression Loss:  7.498988890330548e-07
# Classification Loss:  8.280068308252978e-05
# BBOX Regression Loss:  7.216708986056296e-07
# Classification Loss:  8.131375372478805e-05
# BBOX Regression Loss:  6.968078701498194e-07
# Classification Loss:  7.991224216918152e-05
# BBOX Regression Loss:  6.736141181641466e-07
# Classification Loss:  7.856789398593484e-05
# BBOX Regression Loss:  6.516326808465506e-07
# Classification Loss:  7.728861334423224e-05
# BBOX Regression Loss:  7.311607353102894e-07
# Classification Loss:  7.607907784044926e-05
# BBOX Regression Loss:  0.0001538843481140493
# Classification Loss:  7.508397582800141e-05
# BBOX Regression Loss:  0.0007248064790183485
# Classification Loss:  7.834552864854533e-05
# BBOX Regression Loss:  0.0007489576796218702
# Classification Loss:  8.492563053996229e-05
# BBOX Regression Loss:  0.0007108507832577339
# Classification Loss:  9.07973779572381e-05
# BBOX Regression Loss:  0.00011875580142562588
# Classification Loss:  0.00013827849351973447
# BBOX Regression Loss:  8.25961202348548e-05
# Classification Loss:  0.000134740372326363
# BBOX Regression Loss:  6.103443151072565e-05
# Classification Loss:  0.00013078457710367664
# BBOX Regression Loss:  4.766646018618269e-05
# Classification Loss:  0.00012702258170099447
# BBOX Regression Loss:  3.880452862412548e-05
# Classification Loss:  0.00012342735538604084
# BBOX Regression Loss:  3.263805716010716e-05
# Classification Loss:  0.00012008369308149004
# BBOX Regression Loss:  2.8151554445603374e-05
# Classification Loss:  0.00011701569128683004
# BBOX Regression Loss:  2.4758392912729132e-05
# Classification Loss:  0.00011405595244098179
# BBOX Regression Loss:  2.2106400254774658e-05
# Classification Loss:  0.00011122466846840616
# BBOX Regression Loss:  1.997744825968295e-05
# Classification Loss:  0.00010854973095572658
# BBOX Regression Loss:  7.482848458393062e-07
# Classification Loss:  8.07204835668758e-05
# BBOX Regression Loss:  7.110408390602701e-07
# Classification Loss:  7.904459920677321e-05
# BBOX Regression Loss:  6.789273637552448e-07
# Classification Loss:  7.744736043897308e-05
# BBOX Regression Loss:  6.519312356195533e-07
# Classification Loss:  7.594110448499798e-05
# BBOX Regression Loss:  6.277127505637947e-07
# Classification Loss:  7.45483445590017e-05
# BBOX Regression Loss:  6.048014155466162e-07
# Classification Loss:  7.322846076819172e-05
# BBOX Regression Loss:  5.837808732404101e-07
# Classification Loss:  7.197191444762722e-05
# BBOX Regression Loss:  5.974493677530079e-07
# Classification Loss:  7.078051744934379e-05
# BBOX Regression Loss:  1.1256731574385525e-05
# Classification Loss:  6.963586192309795e-05
# BBOX Regression Loss:  0.00041627482410654516
# Classification Loss:  6.95372888111268e-05
# BBOX Regression Loss:  0.0011924057491813547
# Classification Loss:  9.216412608684215e-05
# BBOX Regression Loss:  0.0007975855436934918
# Classification Loss:  9.588511721058577e-05
# BBOX Regression Loss:  0.0005780379061535414
# Classification Loss:  9.685817525296668e-05
# BBOX Regression Loss:  0.00044570863166073756
# Classification Loss:  9.654383972735592e-05
# BBOX Regression Loss:  0.00036040985670061443
# Classification Loss:  9.55435380132662e-05
# BBOX Regression Loss:  0.0003015707563104059
# Classification Loss:  9.411827799070764e-05
# BBOX Regression Loss:  0.00025892909551749227
# Classification Loss:  9.244698723137536e-05
# BBOX Regression Loss:  0.00022676839444607644
# Classification Loss:  9.06971672386e-05
# BBOX Regression Loss:  0.0002016848144860442
# Classification Loss:  8.893685651092249e-05
# BBOX Regression Loss:  0.0001815927927580358
# Classification Loss:  8.721159352851964e-05
# BBOX Regression Loss:  6.484582155718711e-07
# Classification Loss:  6.876436872752729e-05
# BBOX Regression Loss:  6.160163020804583e-07
# Classification Loss:  6.744388439175155e-05
# BBOX Regression Loss:  5.860737361711663e-07
# Classification Loss:  6.624660813997007e-05
# BBOX Regression Loss:  5.624399810349805e-07
# Classification Loss:  6.50876611298709e-05
# BBOX Regression Loss:  5.418839518151126e-07
# Classification Loss:  6.399861243725928e-05
# BBOX Regression Loss:  5.22551729290295e-07
# Classification Loss:  6.295955778720478e-05
# BBOX Regression Loss:  6.27155555708601e-07
# Classification Loss:  6.194654593451155e-05
# BBOX Regression Loss:  0.00010842034493963284
# Classification Loss:  6.115958585050301e-05
# BBOX Regression Loss:  0.0013091677866116703
# Classification Loss:  8.608294730438802e-05
# BBOX Regression Loss:  0.0014411939222841114
# Classification Loss:  0.00011300224978994165
# BBOX Regression Loss:  0.0009267033388217291
# Classification Loss:  0.00032484729049934286
# BBOX Regression Loss:  0.0006334181590419676
# Classification Loss:  0.0003041557433014667
# BBOX Regression Loss:  0.0004659558195091876
# Classification Loss:  0.00028641050577991536
# BBOX Regression Loss:  0.0003634323092194757
# Classification Loss:  0.00026964363512686556
# BBOX Regression Loss:  0.0002958999912651187
# Classification Loss:  0.000254479611499442
# BBOX Regression Loss:  0.0002488217029661618
# Classification Loss:  0.0002410379370651495
# BBOX Regression Loss:  0.00021439228882420583
# Classification Loss:  0.00022920176421326619
# BBOX Regression Loss:  0.00018825229961765688
# Classification Loss:  0.0002186969304198606
# BBOX Regression Loss:  0.00016776745957001438
# Classification Loss:  0.00020931436365983857
# BBOX Regression Loss:  0.0001512988589739608
# Classification Loss:  0.00020086195121553758
# BBOX Regression Loss:  2.526533137791342e-06
# Classification Loss:  0.0001165817405476614
# BBOX Regression Loss:  2.3269650800675325e-06
# Classification Loss:  0.00011296436294085449
# BBOX Regression Loss:  2.1594402408672867e-06
# Classification Loss:  0.00010967034024450882
# BBOX Regression Loss:  2.0167564428077265e-06
# Classification Loss:  0.00010657496060486194
# BBOX Regression Loss:  1.901905432330548e-06
# Classification Loss:  0.00010363728584100803
# BBOX Regression Loss:  4.262836457066307e-06
# Classification Loss:  0.00010089575295784961
# BBOX Regression Loss:  0.0002582199994653892
# Classification Loss:  0.0001002860695330633
# BBOX Regression Loss:  0.00031964181376275115
# Classification Loss:  0.00010129648456953604
# BBOX Regression Loss:  0.0003086206760895132
# Classification Loss:  0.00010228894033887013
# BBOX Regression Loss:  0.0002862825906885081
# Classification Loss:  0.00010261900516019927
# BBOX Regression Loss:  2.8463786131598886e-05
# Classification Loss:  9.993165903897196e-05
# BBOX Regression Loss:  1.9675067408200075e-05
# Classification Loss:  9.707854500178386e-05
# BBOX Regression Loss:  1.4774187819753414e-05
# Classification Loss:  9.427131958489802e-05
# BBOX Regression Loss:  1.1656703948877596e-05
# Classification Loss:  9.16391397671153e-05
# BBOX Regression Loss:  9.60962885949778e-06
# Classification Loss:  8.93089511535234e-05
# BBOX Regression Loss:  8.18967188294024e-06
# Classification Loss:  8.716014958343202e-05
# BBOX Regression Loss:  7.152216906351943e-06
# Classification Loss:  8.50536154642228e-05
# BBOX Regression Loss:  6.362540089126182e-06
# Classification Loss:  8.302113182489175e-05
# BBOX Regression Loss:  5.740804457965157e-06
# Classification Loss:  8.10968531046538e-05
# BBOX Regression Loss:  5.237248120398295e-06
# Classification Loss:  7.926921894842827e-05
# BBOX Regression Loss:  6.428727189173784e-07
# Classification Loss:  6.021916116070417e-05
# BBOX Regression Loss:  6.210840823499624e-07
# Classification Loss:  5.9089669957757e-05
# BBOX Regression Loss:  1.466051756402903e-06
# Classification Loss:  5.7995453890826965e-05
# BBOX Regression Loss:  0.00037037468728158275
# Classification Loss:  5.7215019694046565e-05
# BBOX Regression Loss:  0.0009314366427753594
# Classification Loss:  6.0935826040804394e-05
# BBOX Regression Loss:  0.00087721607812713
# Classification Loss:  6.69335876016613e-05
# BBOX Regression Loss:  0.000783738030311907
# Classification Loss:  7.188557585573229e-05
# BBOX Regression Loss:  0.0006949893207716001
# Classification Loss:  7.525757871378489e-05
# BBOX Regression Loss:  0.0006211918510360439
# Classification Loss:  7.730106901714708e-05
# BBOX Regression Loss:  0.0005601644210064142
# Classification Loss:  7.840954422674799e-05
# BBOX Regression Loss:  4.857643782290527e-06
# Classification Loss:  8.33769380632374e-05
# BBOX Regression Loss:  3.472130582075032e-06
# Classification Loss:  8.104992556144243e-05
# BBOX Regression Loss:  2.714543806189199e-06
# Classification Loss:  7.875890379058726e-05
# BBOX Regression Loss:  2.243532677918362e-06
# Classification Loss:  7.667598127025283e-05
# BBOX Regression Loss:  1.9308209583094273e-06
# Classification Loss:  7.480849615401691e-05
# BBOX Regression Loss:  1.70975639843231e-06
# Classification Loss:  7.313671054743967e-05
# BBOX Regression Loss:  1.5453435692328854e-06
# Classification Loss:  7.148882129017716e-05
# BBOX Regression Loss:  1.4170365143736826e-06
# Classification Loss:  6.98817330649709e-05
# BBOX Regression Loss:  1.3145751529510962e-06
# Classification Loss:  6.834160322860006e-05
# BBOX Regression Loss:  1.2296653285712065e-06
# Classification Loss:  6.686994219543758e-05
# BBOX Regression Loss:  4.3035601669948346e-07
# Classification Loss:  5.150236473936174e-05
# BBOX Regression Loss:  4.328983322920976e-07
# Classification Loss:  5.057388356093455e-05
# BBOX Regression Loss:  6.433131985420599e-06
# Classification Loss:  4.969057900095243e-05
# BBOX Regression Loss:  0.0006183426896406539
# Classification Loss:  4.9727951948255026e-05
# BBOX Regression Loss:  0.0006819402747452033
# Classification Loss:  5.2196509808439895e-05
# BBOX Regression Loss:  0.0006197845688482765
# Classification Loss:  5.4849292306850345e-05
# BBOX Regression Loss:  0.0005447725260454663
# Classification Loss:  5.674491896387682e-05
# BBOX Regression Loss:  0.0004812161553752924
# Classification Loss:  5.7918119300329296e-05
# BBOX Regression Loss:  0.0004293026148963407
# Classification Loss:  5.8531083181929687e-05
# BBOX Regression Loss:  0.0003868722136646991
# Classification Loss:  5.8768517768907336e-05
